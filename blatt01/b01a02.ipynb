# %% [markdown]
# # Aufgabe 2

# %%
codeword = "emrssommrmsttsmrmmossrme"

# %%
# 2.1
list_codeword = list(codeword)
list_codeword
# Out:
# ['e',
#  'm',
#  'r',
#  's',
#  's',
#  'o',
#  'm',
#  'm',
#  'r',
#  'm',
#  's',
#  't',
#  't',
#  's',
#  'm',
#  'r',
#  'm',
#  'm',
#  'o',
#  's',
#  's',
#  'r',
#  'm',
#  'e']

# %%
# 2.2
a = list_codeword[0::2]
a
# Out:
# ['e', 'r', 's', 'm', 'r', 's', 't', 'm', 'm', 'o', 's', 'm']

# %%
#2.3
b = a[0:-5]
c = a[-5:]
print(b)
print(c)
# Out:
# ['e', 'r', 's', 'm', 'r', 's', 't']
# ['m', 'm', 'o', 's', 'm']

# %%
# 2.4
d = b[:1]
e = b[1:]
f = d * 4
print(d)
print(e)
print(f)
# Out:
# ['e']
# ['r', 's', 'm', 'r', 's', 't']
# ['e', 'e', 'e', 'e']

# %%
# 2.5
g = f + e
h = g[0::4]
i = g[1::4]
j = g[2::4]
k = g[3::4]
print(g)
print(h)
print(i)
print(j)
print(k)
# Out:
# ['e', 'e', 'e', 'e', 'r', 's', 'm', 'r', 's', 't']
# ['e', 'r', 's']
# ['e', 's', 't']
# ['e', 'm']
# ['e', 'r']

# %%
# 2.6
l = h + j + i + k
l
# Out:
# ['e', 'r', 's', 'e', 'm', 'e', 's', 't', 'e', 'r']

# %%
# 2.7
c.pop()
c.reverse()
m = c
m
# Out:
# ['s', 'o', 'm', 'm']

# %%
# 2.8
result = "".join(m + l) + " " + str(len(codeword))
result
# Out:
# 'sommersemester 24'
