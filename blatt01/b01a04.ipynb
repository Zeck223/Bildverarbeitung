# %%
import numpy as np

# %%
# 4.1
u = np.full((9, ), 2)
u
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
# 4.2
liste = [8, 7, 6, 5, 4, 3, 2, 1, 0]
v = np.array(liste)
v.dtype
# Out:
# dtype('int64')

# %%
# 4.3
v[2] = 1
v
# Out:
# array([8, 7, 1, 5, 4, 3, 2, 1, 0])

# %%
# 4.4
prod = u * v
prod
# Out:
# array([16, 14,  2, 10,  8,  6,  4,  2,  0])

# %%
# 4.5
m = v.reshape(3, 3)
m
# Out:
# array([[8, 7, 1],
#        [5, 4, 3],
#        [2, 1, 0]])

# %%
# 4.6
n = m + 2.4
print(n)
print(m.dtype)
print(n.dtype)
# Out:
# [[10.4  9.4  3.4]
#  [ 7.4  6.4  5.4]
#  [ 4.4  3.4  2.4]]
# int64
# float64

# %%
# 4.7
sum_n = np.sum(n) 
sum_n
# Out:
# np.float64(52.6)
