# %% [markdown]
# # Lehrevaluation
#
# Es ist Zeit für die Lehrevaluation. Nehmt euch bitte ein paar Minuten Zeit, um die Lehrebvaluation für VL und Übung durchzuführen (zwei Fragebögen). Euer Feedback ist entscheidend für die Weiterentwickling der Veranstaltung und um die Qualiät weiter zu verbessern. In den letzten Jahren könnten wir so immer wieder auf die Wünsche von Studis eingehen und Anpassungen vornehmen.
#
# Die Links findet ihr auch im Moodle. Die Teilnahme an beiden Umfragen ist bis zum 26.06. möglich.

# %% [markdown]
# # Fragebogen für die Vorlesungen von Christian
#
# [Hier geht's lang](https://evasys-online.uni-hamburg.de/evasys/online.php?pswd=FEGAK)
#
# ![QRCode_FEGAK_VL.png](attachment:QRCode_FEGAK_VL.png)

# %% [markdown]
# # Fragenbogen für die Übungen
#
# [Hier geht's lang](
# https://evasys-online.uni-hamburg.de/evasys/online.php?pswd=K3UCG)
#
# ![QRCode_K3UCG_Uebung.png](attachment:QRCode_K3UCG_Uebung.png)

# %% [markdown]
# Im Rahmen dieser Aufgabe werden wir Kanten aus dem Mandrillbild extrahieren und die Folgen der Anwendung eines Gauß-Filters darauf betrachten. Zunächst laden wir dafür das Bild und zeigen es an.

# %%
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.filters import *
import numpy as np
#from skimage.data import brick

img = imread('mandrill.png')
#img = brick()
#img = imread('brick.png') #falls Version von skimage zu alt

plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Berechnet die Gradientenstärke einmal nach Sobel und einmal nach Prewitt für jedes Pixel im Bild und visualisiert die Ergebnisse. Wie unterscheiden sich die Ergebnisse? Versucht einen Grenzwert für die Gradientenstärke so zu finden, dass nur noch für das Gesicht relevante Kanten übrig bleiben. Ist dies möglich?

# %% [markdown]
# Wendet nun zunächst einen Gauß-Filter auf das Bild an und berechnet danach die Gradientenstärke nach Sobel. Wie verändert sich das Ergebnis mit steigendem `sigma`? Kann der Grenzwert für die Gradientensträke unverändert bleiben?

# %% [markdown]
# Extrahiert nun die Bildzeile 150 aus dem Bild nach Anwendung des Gauß-Filters mit `sigma=2` und aus dem Bild nach Anwendung des Gauß-Filters mit `sigma=5`.
#
# Berechnet außerdem den horizontalen Gradienten (vertikale Kanten) auf den drei (kompletten) Bildern und extrahiert aus den jeweiligen Ergebnissen wieder Bildzeile 150.
#
# Plottet nun die beiden Ergebnisse für die drei Bilder jeweils in einen Plot als Funktiongraph. Was ist im Funktiongraphen zu sehen?

# %% [markdown]
# Berechnet nun die Orientierung aller Gradienten für das Originalbild. Lasst euch das Ergebnis mit matplotlib anzeigen. Welche Parameter müsst ihr dazu bei `imshow` wählen und was sagt euch das Ergebnis? Wie verändert sich das Ergebnis, wenn ihr zunächst wieder das Bild mit einem Gauß-Filter weichzeichnet? Nutzt dazu auch das `brick`-Bild für diese Teilaufgabe.
#
# Tipp: Nutzt `cmap='hsv'` im Aufruf von `imshow` und plottet die Colorbar mit `plt.colorbar()`.
