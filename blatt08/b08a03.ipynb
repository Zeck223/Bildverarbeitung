# %% [markdown]
# # Aufgabe 3

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
rImg = np.loadtxt("ergebnis_Aufgabe2.csv")
plt.imshow(rImg, cmap="gray")
plt.title("Ergebnis der Aufgabe 2")
# Out:
# Text(0.5, 1.0, 'Ergebnis der Aufgabe 2')
