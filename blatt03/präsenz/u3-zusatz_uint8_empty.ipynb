# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage.io as skio

# %% [markdown]
# Ladet und plottet das Bild ```grayscale.png```
#
# *Alternativ*: erstellt das Bild selber nach folgenden Angaben: \
# Erstellt ein Bild der Größe 256x256 mit Datentypt ```uint8``` in welchem der Helligkeitswert spaltenweise um 1 zunimmt
#
# $\begin{bmatrix}
# 0&1&\dots&254&255\\
# \vdots&\vdots&&\vdots&\vdots\\
# 0&1&\dots&254&255
# \end{bmatrix}$

# %% [markdown]
# Führt nun verschiedene arithmetische Operationen auf und zeigt jeweils das Ergebnis mit ```plt.imshow(...)``` an.
#
# 1. addiert den Wert 100 auf das ursprüngliche Bild (was würdet ihr optisch erwarten, was ist das tatsächliche Ergebnis?)

# %% [markdown]
# 2. Multipliziert das ursprüngliche Bild mit dem Wert 3 (was würdet ihr optisch erwarten, was ist das tatsächliche Ergebnis?)

# %% [markdown]
# 3. Multipliziert das ursprüngliche Bild mit dem Wert 3 und teilt anschließend (ganzzahlig) durch 3 (was würdet ihr optisch erwarten, was ist das tatsächliche Ergebnis?)

# %% [markdown]
# Woran liegt das? Wie könnte man dieses Problem beim Programmieren umgehen?
